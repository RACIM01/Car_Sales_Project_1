# %%
import pandas as pd
import numpy as np 
import ydata_profiling as pp

# %%
# read data
df = pd.read_csv(r"C:\Users\GTR\Documents\GitHub\cars_sales\raw_data\USA_cars_datasets.csv")
# drop useless columns
df.drop(['Unnamed: 0',"lot","vin"], axis=1,inplace=True)
# add kilometre column
df["kilometre"] = df["mileage"] * 1.60934

# %%
df.isnull().sum()
# Out:
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# state           0
# country         0
# condition       0
# kilometre       0
# dtype: int64

# %%
df.head()
# Out:
#    price      brand    model  year   title_status   mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle  274117.0   black
# 1   2899       ford       se  2011  clean vehicle  190552.0  silver
# 2   5350      dodge      mpv  2018  clean vehicle   39590.0  silver
# 3  25000       ford     door  2014  clean vehicle   64146.0    blue
# 4  27700  chevrolet     1500  2018  clean vehicle    6654.0     red
#
#         state country      condition     kilometre
# 0  new jersey     usa   10 days left  441147.45278
# 1   tennessee     usa    6 days left  306662.95568
# 2     georgia     usa    2 days left   63713.77060
# 3    virginia     usa  22 hours left  103232.72364
# 4     florida     usa  22 hours left   10708.54836

# %%
pp.ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-12-17 21:24:30.389187&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.to_csv(r"C:\Users\GTR\Documents\GitHub\cars_sales\ETL_data\USA_cars_datasets_c.csv")
